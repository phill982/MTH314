# %% [markdown]
# # Vector spaces II

# %% [markdown]
# ### Fundamental Spaces:
#
#
#
# ![linear-algebra-fundamental-space-interpretation-6.png](attachment:linear-algebra-fundamental-space-interpretation-6.png)

# %% [markdown]
# <font color='blue'>**Example**. Consider the matrix
# $
# A=\begin{bmatrix}
#  1 & 0 & -3 & 2\\0 &1 & -5 & 4\\3 & -2 & 1 &-2
# \end{bmatrix}
# $

# %% [markdown]
# <font color='blue'> $\text{col}(A)$ is a subspace of some $\mathbb{R}^k$. What is $k$?

# %%
#Put your answer here

# %% [markdown]
# <font color='blue'> $\text{null}(A)$ is a subspace of some $\mathbb{R}^k$. What is $k$?

# %%
#Put your answer here

# %% [markdown]
# <font color='blue'> Using Python, find the reduced row echelon form (RREF) of $A$.

# %%
# Put your code here
import numpy as np
import sympy as sym
A= np.array([[1,0,-3,2],[0,1,-5,4],[3,-2,1,-2]])
#
# Out:
# Matrix([
# [1, 0, -3, 2],
# [0, 1, -5, 4],
# [0, 0,  0, 0]])

# %% [markdown]
# <font color='blue'>By interprestting the RREF, find a basis for the rowspace $\text{row}(A)$, i.e. the span of the rows of $A$.

# %% [markdown]
# row(A)= span{$[1,0,-3,2],[0,1,-5,4]$}

# %% [markdown]
# <font color='blue'>By interprestting the RREF, find a basis for the column space $\text{col}(A)$, i.e. the span of the columns of $A$.

# %%
#Put your answer here

# %% [markdown]
# <font color='blue'> Does the vector $
# \begin{bmatrix}
#  1 \\0 \\3
# \end{bmatrix}
# $ belong to $\text{col}(A)$?

# %%
#Put your answer here

# %% [markdown]
# <font color='blue'> Does the vector $
# \begin{bmatrix}
#  2 \\-1 \\1
# \end{bmatrix}
# $ belong to $\text{col}(A)$?

# %%
#Put your answer here; justify

# %% [markdown]
# <font color='blue'> By interprestting the RREF, find a basis for the null space $\text{null}(A)$, i.e. the set of all solutions to $A\vec{x} = \vec{0}$.

# %% [markdown]
# <font color='blue'> Does the vector $
# \begin{bmatrix}
#  3 \\5 \\2\\0
# \end{bmatrix}
# $ belong to $\text{null}(A)$?

# %%
#Put your answer here

# %% [markdown]
# <font color='blue'>By interprestting the RREF, what is the rank of $A$? How are the rank, dimension of the null space and the size of $A$ related?

# %%
#Put your answer here

# %% [markdown]
# <font color='blue'> What is  $\dim\left(\text{null}(A^T)\right)$? Justify your answer.

# %%
#Put your answer here

# %% [markdown]
# <font color='blue'> Calculate the dot product of each basis vector of $\text{null}(A)$ with each basis vector of $\text{row}(A)$. What do you notice? What does your observation imply?

# %% [markdown]
# <font color='blue'> Calculate the dot product of each basis vector of $\text{col}(A)$ with each basis vector of $\text{null}(A^T)$. What do you notice? What does your observation imply?

# %%
#

# %% [markdown]
# ----
#
# <font color='blue'>**Example**. Write a function on python that does the following:\
#     (a). Has an input a matrix $A$ and calculates its reduced row echelon form.\
#     (b). Finds a basis for the row space by interpeting the RREF and prints its dimension.\
#     (c). Finds a column space by interpeting the RREF and prints its dimension.

# %%
def bases(A):
    #Make A in a sym Matrix
        A = 
    #Reduce to row echelon form
        M = 
    # Row space first:
        #Get it back to an np.array.
        V = np.array(M.tolist())
        # Use np.all to delete the 0 rows.
        V = V[~np.all(V == 0, axis=1)]
        # Make V a sym Matrix again and return it.
        V=
        print(f"The dimension of the row space is {...}")
        print("the basis of the row space is",...)
    # Column space now:
        #Find pivot columns 
        pivot_cols = ...
        # Create a matrix W by taking columns from A that correspond to pivot columns
        W = 
        print(f"The dimension of the column space is {...}")
        print("The columns of the following matrix are basis vectors of the column space",...)

# %% [markdown]
# <font color='blue'>  Test your function with the matrix A of the previous and check if the two answers match.

# %%
#

# %% [markdown]
# <font color='blue'>  One more test:

# %%
C = sym.Matrix([[1,-4,8,1],
               [-1,4,-8,4],
               [-2,10,-17,1]])

# %%
#
